# %%
import os 

train_data = "BrainTumorYolov8/train"

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="BrainTumorYolov8/data.yaml",
    epochs=50,
    imgsz=640,
    device="cpu"
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.77 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.75 🚀 Python-3.13.7 torch-2.7.1+cu118 CPU (11th Gen Intel Core i5-1135G7 @ 2.40GHz)
# ...

# %%
import torch

print("PyTorch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# PyTorch: 2.7.1+cu118
# CUDA available: True
# GPU: NVIDIA GeForce MX330

# %%
metrics = model.val()
print(metrics)
# Out:
# Ultralytics 8.4.75 🚀 Python-3.13.7 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce MX330, 1994MiB)
# Model summary (fused): 73 layers, 3,006,233 parameters, 13,065 gradients
#
# WARNING ⚠️ Dataset 'coco.yaml' images not found, missing path '/home/supriya-devkota/Desktop/DSML/DSML_project/brain_tumor_project/datasets/coco/val2017.txt'
# ...
# Unzipping /home/supriya-devkota/Desktop/DSML/DSML_project/brain_tumor_project/datasets/coco2017labels-segments.zip to /home/supriya-devkota/Desktop/DSML/DSML_project/brain_tumor_project/datasets/coco...: 15% ━╸────────── 19349/122232 7.2Kfiles/s 2.8s<14.3s

# %%
import numpy as np
import pandas as pd
import cv2

# %%
image_dir = '/home/supriya-devkota/Desktop/DSML/DSML_project/BrainTumorYolov8/train/images'
label_dir = '/home/supriya-devkota/Desktop/DSML/DSML_project/BrainTumorYolov8/train/labels'

# %%
images = []
labels = []

# %%
for image_file in sorted(os.listdir(image_dir)):
    if image_file.lower().endswith(('.jpg','.png','.jpeg')):

        image_path = os.path.join(image_dir, image_file)

        image = cv2.imread(image_path)

        if image is not None:
            images.append(image)

        label_file = os.path.split(image_file)[0] + '.txt'
        label_path = os.path.join(label_dir, label_file)    

        if os.path.exists(label_path):
            with open(label_file, "r") as f:
                label_data = f.readline()

                labels.append(label_data)

        else:
            labels.append([])

# %%
print("Total image: ", len(images))
print("Total labels: ", len(labels))
# Out:
# Total image:  2144
# Total labels:  2144

# %%
# !pip install tensorflow[and-cuda]
# Out:
# ...
#   Using cached absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# ...
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# ...
#   Using cached gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# ...
#   Using cached libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# ...
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached protobuf-7.35.1-cp310-abi3-manylinux2014_x86_64.whl.metadata (595 bytes)
# ...
#   Using cached termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.9.2.10-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.9.79-py3-none-manylinux_2_25_x86_64.whl.metadata (1.8 kB)
# ...
#   Using cached nvidia_cuda_nvcc_cu12-12.9.86-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# ...
